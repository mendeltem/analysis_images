# %%
import pickle
import matplotlib.pyplot as plt

# %%
history = pickle.load( open( "trainHistoryDict", "rb" ) )

# %% [markdown]
# type(train_history)

# %%
history.keys()
# Out:
# dict_keys(['val_loss', 'val_dice_loss', 'loss', 'dice_loss'])

# %%
history['loss'][-1]
# Out:
# 0.8761424113270695

# %%
history['val_loss'][-1]
# Out:
# 1.154552749461598

# %%
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
plt.plot(history['dice_loss'])
plt.plot(history['val_dice_loss'])
plt.title('loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
